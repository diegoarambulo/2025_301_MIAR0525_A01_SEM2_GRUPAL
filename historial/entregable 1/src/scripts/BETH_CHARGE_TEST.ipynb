# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "labelled_2021may-ip-10-100-1-186.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "katehighnam/beth-dataset",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipython-input-4167690763.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'beth-dataset' dataset.
# First 5 records:     timestamp  processId  parentProcessId  userId      processName  \
# 0  124.952820        383                1     101  systemd-resolve
# 1  124.953139        380                1     100  systemd-network
# 2  124.953424          1                0       0          systemd
# 3  124.953464          1                0       0          systemd
# 4  124.953494          1                0       0          systemd
#
#           hostName  eventId           eventName  argsNum  returnValue  \
# 0  ip-10-100-1-186       41              socket        3           15
# 1  ip-10-100-1-186       41              socket        3           15
# 2  ip-10-100-1-186     1005  security_file_open        4            0
# 3  ip-10-100-1-186      257              openat        4           17
# 4  ip-10-100-1-186        5               fstat        2            0
#
#                                                 args  sus  evil
# 0  [{'name': 'domain', 'type': 'int', 'value': 'A...    0     0
# 1  [{'name': 'domain', 'type': 'int', 'value': 'A...    0     0
# 2  [{'name': 'pathname', 'type': 'const char*', '...    0     0
# 3  [{'name': 'dirfd', 'type': 'int', 'value': -10...    0     0
# 4  [{'name': 'fd', 'type': 'int', 'value': 17}, {...    0     0
